# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import random

#Funtion to roll the dice.
def roll_the_dice(iterations):
    number_of_times = 0
    for i in range(iterations):
        n = random.randint(1, 6) + random.randint(1, 6)
        if ((n>7) or (n%2==0)):
            number_of_times += 1
    prob = round((number_of_times/iterations)*100, 2)
    return prob

simulaciones = 1000
probabilidad = roll_the_dice(simulaciones)

print("La probabilidad (estimada a partir de", simulaciones, "simulaciones) de que la suma sea mayor que 7 o un número par es", str(probabilidad)+"%")
print("(La probabilidad teórica es 66.7%)")
# Out:
# La probabilidad (estimada a partir de 1000 simulaciones) de que la suma sea mayor que 7 o un número par es 66.8%
# (La probabilidad teórica es 66.7%)

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries
import random
import numpy as np

d = {}

for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'  

        
#Initialize important variables
n_simulations = 50000
cantidad_5_iguales = 0
cantidad_3b_2r = 0

for i in range(n_simulations):
    
    #make a list of the colors that we choose
    lista_colores = []

    for j in range(5):
        lista_colores.append(d[random.randint(0, 59)])
        # No entiendo por qué funciona lo anterior pero no hacer:
        # num_random = random.randint(0, 59)
        # lista_colores.append(d[num_random])
        
    #Convert it to a numpy array
    array_colores = np.array(lista_colores)

    #find the number of each that we picked
    cant_blanco = sum(array_colores == 'White')
    cant_rojo = sum(array_colores == 'Red')
    cant_verde = sum(array_colores == 'Green')
    
    #Keep track if the combination met the criteria
    if (cant_blanco == 5) or (cant_rojo == 5) or (cant_verde == 5):
        cantidad_5_iguales += 1
    elif (cant_blanco == 3) and (cant_rojo == 2):
        cantidad_3b_2r += 1

prob_5_iguales = round((cantidad_5_iguales/n_simulations)*100, 2)
prob_3b_2r = round((cantidad_3b_2r/n_simulations)*100, 2)
    
    
#print 'the probability of 3 white and 2 red is' in percentage
print("La probabilidad (estimada a partir de", n_simulations, "simulaciones) de 3 blancas y 2 rojas es", str(prob_3b_2r)+"%")
print("(La probabilidad teórica es 0.51%)")
print()

#print 'the probability of all the same color is' in percentage  
print("La probabilidad (estimada a partir de", n_simulations, "simulaciones) de todas del mismo color es", str(prob_5_iguales)+"%") 
print("(La probabilidad teórica es 3.55%)")
# Out:
# La probabilidad (estimada a partir de 50000 simulaciones) de 3 blancas y 2 rojas es 0.5%
# (La probabilidad teórica es 0.51%)
#
# La probabilidad (estimada a partir de 50000 simulaciones) de todas del mismo color es 3.53%
# (La probabilidad teórica es 3.55%)
